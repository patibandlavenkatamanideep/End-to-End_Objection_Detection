# %%
import os
from sys import prefix

# %%
# %pwd
# Out:
# '/Users/manideep/PycharmProjects/PythonProject/End-to-End Objection Detection/notebook'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/manideep/PycharmProjects/PythonProject/End-to-End Objection Detection'

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/19npolE9IcjL6kUKjQanOx2EF_-iiVZcv/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '19npolE9IcjL6kUKjQanOx2EF_-iiVZcv'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "sign_language_data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=19npolE9IcjL6kUKjQanOx2EF_-iiVZcv
# To: /Users/manideep/PycharmProjects/PythonProject/End-to-End Objection Detection/sign_data.zip
# 100%|██████████| 10.3M/10.3M [00:00<00:00, 14.2MB/s]
# 'sign_data.zip'
